# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs

# %%
#generate data
X,y=make_blobs(n_samples=200,centers=5)
print(X.shape,y.shape)
# Out:
# (100, 2) (100,)

# %%
#plotting the data
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
#import K-means from sklearn
from sklearn.cluster import KMeans

# %%
clf=KMeans(n_clusters=5)
clf.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#cluster labels
clf.labels_
# Out:
# array([0, 1, 4, 4, 3, 3, 1, 4, 2, 1, 3, 3, 1, 1, 0, 2, 2, 3, 4, 4, 0, 0,
#        1, 0, 1, 4, 3, 4, 0, 3, 3, 0, 3, 1, 3, 1, 3, 1, 1, 2, 2, 4, 0, 0,
#        3, 4, 2, 4, 4, 0, 0, 3, 3, 3, 3, 1, 1, 2, 1, 2, 1, 4, 2, 4, 1, 2,
#        2, 4, 4, 3, 2, 4, 1, 2, 3, 0, 4, 0, 0, 0, 1, 2, 0, 3, 2, 4, 2, 1,
#        1, 0, 4, 2, 2, 2, 3, 4, 0, 2, 0, 0])

# %%
#mean points of the cluster
z=clf.cluster_centers_
print(z)
# Out:
# [[-5.48984777 -9.0655179 ]
#  [ 3.16125905  1.84517124]
#  [10.21860547 -7.92315617]
#  [-5.78543502  9.06110401]
#  [ 8.53212505 -9.60449252]]

# %%
#plotting the clusters with their mean centers
plt.scatter(X[:,0],X[:,1],c=clf.labels_)
plt.scatter(z[:,0],z[:,1],c='blue')
plt.show()
